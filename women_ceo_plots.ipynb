# %%
import os
import matplotlib.pyplot as plt
files = os.listdir('outputs/')
#files.remove('.DS_Store')

# %%
for i in files:
    plt.figure(figsize=(10, 12))
    plt.imshow(plt.imread('plots/{}'.format(i)))
    plt.title(i.split('.')[0])
    plt.show()
